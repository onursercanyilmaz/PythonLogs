# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Iris.csv")

# %%
print(df.columns)
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
print(df.Species.unique())
# Out:
# ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB
# None

# %%
print(df.describe())
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
setosa = df[df.Species == "Iris-setosa"]
versicolor = df[df.Species == "Iris-versicolor"]
virginica = df[df.Species == "Iris-virginica"]

# %%
print(setosa.describe())               #sepal: çanak yaprak #petal: tac yaprak
print(versicolor.describe())
print(virginica.describe())
# Out:
#              Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  50.00000       50.00000     50.000000      50.000000      50.00000
# mean   25.50000        5.00600      3.418000       1.464000       0.24400
# std    14.57738        0.35249      0.381024       0.173511       0.10721
# min     1.00000        4.30000      2.300000       1.000000       0.10000
# 25%    13.25000        4.80000      3.125000       1.400000       0.20000
# 50%    25.50000        5.00000      3.400000       1.500000       0.20000
# 75%    37.75000        5.20000      3.675000       1.575000       0.30000
# max    50.00000        5.80000      4.400000       1.900000       0.60000
#               Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count   50.00000      50.000000     50.000000      50.000000     50.000000
# mean    75.50000       5.936000      2.770000       4.260000      1.326000
# std     14.57738       0.516171      0.313798       0.469911      0.197753
# ...

# %% [markdown]
# Line PLOT

# %%
df = df.drop(["Id"], axis = 1)

# %%
#setosa = df[df.Species == "Iris-setosa"]
#versicolor = df[df.Species == "Iris-versicolor"]
#virginica = df[df.Species == "Iris-virginica"]

plt.plot(setosa.Id,setosa.PetalLengthCm, color = "red"  , label = "setosa")
plt.plot(versicolor.Id,versicolor.PetalLengthCm, color = "green", label = "versicolor")
plt.plot(virginica.Id,virginica.PetalLengthCm, color = "blue", label = "virginica")

plt.xlabel("Id")
plt.ylabel("PetalLenghtCm")
plt.legend()
plt.show()

# %%
df.plot(grid = True)
plt.show()

# %%
df.plot(grid = True, alpha = 0.5)
plt.show()

# %%
df.plot(grid = True, linestyle = ":")
plt.show()

# %% [markdown]
# Scatter Plot

# %%
#setosa = df[df.Species == "Iris-setosa"]
#versicolor = df[df.Species == "Iris-versicolor"]
#virginica = df[df.Species == "Iris-virginica"]

plt.scatter(setosa.PetalLengthCm,setosa.PetalWidthCm, color="red",label="setosa")
plt.scatter(versicolor.PetalLengthCm,versicolor.PetalWidthCm, color="green",label="versicolor")
plt.scatter(virginica.PetalLengthCm,virginica.PetalWidthCm, color="blue",label="virginica")

plt.legend()
plt.xlabel("PetalLengthCm")
plt.ylabel("PetalWidthCm")
plt.title("Scatter Plot")
plt.show()

# %% [markdown]
# Histogram Plot

# %%
#to see how many data there are for a column
plt.hist(setosa.PetalLengthCm, bins=20)
plt.xlabel("PentalLengthCm Values")
plt.ylabel("frekans")
plt.title("Hist")
plt.show()

# %% [markdown]
# Subplot

# %%
df.plot(grid=True, alpha=0.9, subplots = True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000220352BFD08>,
# ...
#       dtype=object)

# %%
plt.subplot(2,1,1)
plt.plot(setosa.Id,setosa.PetalLengthCm, color = "red"  , label = "setosa")
plt.ylabel("setosa - PetalLen")

plt.subplot(2,1,2)
plt.plot(versicolor.Id,versicolor.PetalLengthCm, color = "green", label = "versicolor")
plt.ylabel("versicolor - PetalLen")
# Out:
# Text(0, 0.5, 'versicolor - PetalLen')

# %% [markdown]
# Bar Plot

# %%
import numpy as np

x = np.array(["Turkey","USA","England","Canada","Brazil","Argentina","Israel"])
y = np.array([868 , 5257 ,3481, 3745 , 762, 1033 , 3410 ])

plt.bar(x,y)
plt.title("Average monthly income of countries")
plt.xlabel("Countries")
plt.ylabel("Dollar")
plt.show()

#is there a relation between average monthly income and population...?
